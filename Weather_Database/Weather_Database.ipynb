# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 739

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f78a53023c50f129ff8f3823aa459e00

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
  # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | san quintin
# Processing Record 5 of Set 1 | pacific grove
# Processing Record 6 of Set 1 | alofi
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | olafsvik
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | kirakira
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | gijon
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | bengkulu
# Processing Record 16 of Set 1 | xuddur
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | ibra
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | shingu
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | bandarbeyla
# Processing Record 23 of Set 1 | praia da vitoria
# Processing Record 24 of Set 1 | salalah
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | pangkalanbuun
# Processing Record 27 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | sfantu gheorghe
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | honiara
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | stokmarknes
# Processing Record 35 of Set 1 | la plata
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | sur
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | puerto baquerizo moreno
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | haines junction
# Processing Record 42 of Set 1 | hambantota
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | krasnoselkup
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | cedar city
# Processing Record 49 of Set 1 | namibe
# Processing Record 50 of Set 1 | lagoa
# Processing Record 1 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 2 | campbell river
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | zaranj
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | vardo
# Processing Record 9 of Set 2 | tigil
# Processing Record 10 of Set 2 | kaitangata
# Processing Record 11 of Set 2 | kolda
# Processing Record 12 of Set 2 | fort morgan
# Processing Record 13 of Set 2 | toora-khem
# Processing Record 14 of Set 2 | coulommiers
# Processing Record 15 of Set 2 | mocuba
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | natal
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | rio gallegos
# Processing Record 20 of Set 2 | amethi
# Processing Record 21 of Set 2 | san cristobal
# Processing Record 22 of Set 2 | buala
# Processing Record 23 of Set 2 | morden
# Processing Record 24 of Set 2 | port hardy
# Processing Record 25 of Set 2 | kalamazoo
# Processing Record 26 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 2 | pingliang
# Processing Record 28 of Set 2 | aripuana
# Processing Record 29 of Set 2 | talara
# Processing Record 30 of Set 2 | kavaratti
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | tilichiki
# Processing Record 33 of Set 2 | rorvik
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | archidona
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | marrakesh
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | staryy nadym
# Processing Record 40 of Set 2 | lodeynoye pole
# Processing Record 41 of Set 2 | araripe
# Processing Record 42 of Set 2 | naze
# Processing Record 43 of Set 2 | fukue
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | leh
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | pato branco
# Processing Record 48 of Set 2 | constitucion
# Processing Record 49 of Set 2 | elko
# Processing Record 50 of Set 2 | nosy varika
# Processing Record 1 of Set 3 | esperance
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | hay river
# Processing Record 4 of Set 3 | mugur-aksy
# Processing Record 5 of Set 3 | nome
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | rikitea
# Processing Record 8 of Set 3 | kenai
# Processing Record 9 of Set 3 | kruisfontein
# Processing Record 10 of Set 3 | richards bay
# Processing Record 11 of Set 3 | kloulklubed
# Processing Record 12 of Set 3 | charters towers
# Processing Record 13 of Set 3 | vila do maio
# Processing Record 14 of Set 3 | westport
# Processing Record 15 of Set 3 | auki
# Processing Record 16 of Set 3 | san jeronimo
# Processing Record 17 of Set 3 | hervey bay
# Processing Record 18 of Set 3 | yerbogachen
# Processing Record 19 of Set 3 | thinadhoo
# Processing Record 20 of Set 3 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 21 of Set 3 | ca mau
# Processing Record 22 of Set 3 | donskoye
# Processing Record 23 of Set 3 | yar-sale
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | nuuk
# Processing Record 27 of Set 3 | souillac
# Processing Record 28 of Set 3 | zaraza
# Processing Record 29 of Set 3 | at-bashi
# Processing Record 30 of Set 3 | geraldton
# Processing Record 31 of Set 3 | kaseda
# Processing Record 32 of Set 3 | maneadero
# Processing Record 33 of Set 3 | beidao
# Processing Record 34 of Set 3 | husavik
# Processing Record 35 of Set 3 | tombouctou
# Processing Record 36 of Set 3 | ballina
# Processing Record 37 of Set 3 | muros
# Processing Record 38 of Set 3 | morondava
# Processing Record 39 of Set 3 | lafiagi
# Processing Record 40 of Set 3 | xining
# Processing Record 41 of Set 3 | tautira
# Processing Record 42 of Set 3 | araouane
# Processing Record 43 of Set 3 | imbituba
# Processing Record 44 of Set 3 | gamba
# Processing Record 45 of Set 3 | rabo de peixe
# Processing Record 46 of Set 3 | banda aceh
# Processing Record 47 of Set 3 | falaleu
# City not found. Skipping...
# Processing Record 48 of Set 3 | sao gabriel da cachoeira
# Processing Record 49 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 50 of Set 3 | jamestown
# Processing Record 1 of Set 4 | yaan
# Processing Record 2 of Set 4 | hilo
# Processing Record 3 of Set 4 | kualakapuas
# Processing Record 4 of Set 4 | laguna de perlas
# Processing Record 5 of Set 4 | minna
# Processing Record 6 of Set 4 | rolla
# Processing Record 7 of Set 4 | moindou
# Processing Record 8 of Set 4 | san patricio
# Processing Record 9 of Set 4 | milkovo
# Processing Record 10 of Set 4 | daru
# Processing Record 11 of Set 4 | saskylakh
# Processing Record 12 of Set 4 | longyearbyen
# Processing Record 13 of Set 4 | salinopolis
# Processing Record 14 of Set 4 | narsaq
# Processing Record 15 of Set 4 | praya
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | half moon bay
# Processing Record 18 of Set 4 | ugoofaaru
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | goiatuba
# Processing Record 21 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 4 | itarema
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | sao felix do xingu
# Processing Record 25 of Set 4 | valdivia
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | fort nelson
# Processing Record 28 of Set 4 | airai
# Processing Record 29 of Set 4 | norman wells
# Processing Record 30 of Set 4 | kankan
# Processing Record 31 of Set 4 | vung tau
# Processing Record 32 of Set 4 | clyde river
# Processing Record 33 of Set 4 | taoudenni
# Processing Record 34 of Set 4 | vao
# Processing Record 35 of Set 4 | beringovskiy
# Processing Record 36 of Set 4 | sobolevo
# Processing Record 37 of Set 4 | leningradskiy
# Processing Record 38 of Set 4 | qaanaaq
# Processing Record 39 of Set 4 | sao filipe
# Processing Record 40 of Set 4 | dikson
# Processing Record 41 of Set 4 | krapivinskiy
# Processing Record 42 of Set 4 | armizonskoye
# Processing Record 43 of Set 4 | kollam
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | sept-iles
# Processing Record 46 of Set 4 | ahipara
# Processing Record 47 of Set 4 | nesna
# Processing Record 48 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 49 of Set 4 | kalabo
# Processing Record 50 of Set 4 | barrow
# Processing Record 1 of Set 5 | wasilla
# Processing Record 2 of Set 5 | benjamin constant
# Processing Record 3 of Set 5 | port hedland
# Processing Record 4 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 5 | babushkin
# Processing Record 6 of Set 5 | caravelas
# Processing Record 7 of Set 5 | catabola
# Processing Record 8 of Set 5 | carnarvon
# Processing Record 9 of Set 5 | acapulco
# Processing Record 10 of Set 5 | saint-philippe
# Processing Record 11 of Set 5 | macomer
# Processing Record 12 of Set 5 | batagay-alyta
# Processing Record 13 of Set 5 | binzhou
# Processing Record 14 of Set 5 | katsuura
# Processing Record 15 of Set 5 | dossor
# Processing Record 16 of Set 5 | salamanca
# Processing Record 17 of Set 5 | la antigua
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | samfya
# Processing Record 20 of Set 5 | ayan
# Processing Record 21 of Set 5 | deputatskiy
# Processing Record 22 of Set 5 | woodbridge
# Processing Record 23 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 5 | botou
# Processing Record 25 of Set 5 | el bosque
# Processing Record 26 of Set 5 | den helder
# Processing Record 27 of Set 5 | aitape
# Processing Record 28 of Set 5 | aksu
# Processing Record 29 of Set 5 | pevek
# Processing Record 30 of Set 5 | zhytomyr
# Processing Record 31 of Set 5 | ngunguru
# Processing Record 32 of Set 5 | kjollefjord
# Processing Record 33 of Set 5 | verkhne-katunskoye
# City not found. Skipping...
# Processing Record 34 of Set 5 | makakilo city
# Processing Record 35 of Set 5 | rawson
# Processing Record 36 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 38 of Set 5 | fortuna
# Processing Record 39 of Set 5 | maniitsoq
# Processing Record 40 of Set 5 | luderitz
# Processing Record 41 of Set 5 | khatanga
# Processing Record 42 of Set 5 | nishihara
# Processing Record 43 of Set 5 | klaksvik
# Processing Record 44 of Set 5 | monchegorsk
# Processing Record 45 of Set 5 | pierre
# Processing Record 46 of Set 5 | arauco
# Processing Record 47 of Set 5 | luxor
# Processing Record 48 of Set 5 | kabompo
# Processing Record 49 of Set 5 | cabo san lucas
# Processing Record 50 of Set 5 | andros town
# Processing Record 1 of Set 6 | nkoteng
# Processing Record 2 of Set 6 | kupino
# Processing Record 3 of Set 6 | ponta do sol
# Processing Record 4 of Set 6 | codajas
# Processing Record 5 of Set 6 | tairua
# Processing Record 6 of Set 6 | charlottesville
# Processing Record 7 of Set 6 | beloha
# Processing Record 8 of Set 6 | port-gentil
# Processing Record 9 of Set 6 | grafton
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | cabedelo
# Processing Record 13 of Set 6 | komsomolskiy
# Processing Record 14 of Set 6 | bilibino
# Processing Record 15 of Set 6 | jatai
# Processing Record 16 of Set 6 | concordia
# Processing Record 17 of Set 6 | esna
# Processing Record 18 of Set 6 | mayo
# Processing Record 19 of Set 6 | natalinsk
# Processing Record 20 of Set 6 | shimoda
# Processing Record 21 of Set 6 | monywa
# Processing Record 22 of Set 6 | leshukonskoye
# Processing Record 23 of Set 6 | coquimbo
# Processing Record 24 of Set 6 | tarnogskiy gorodok
# Processing Record 25 of Set 6 | kathu
# Processing Record 26 of Set 6 | salym
# Processing Record 27 of Set 6 | balkhash
# Processing Record 28 of Set 6 | belmonte
# Processing Record 29 of Set 6 | marathopolis
# City not found. Skipping...
# Processing Record 30 of Set 6 | siparia
# Processing Record 31 of Set 6 | goderich
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | sanandaj
# Processing Record 34 of Set 6 | nago
# Processing Record 35 of Set 6 | morunglav
# Processing Record 36 of Set 6 | raudeberg
# Processing Record 37 of Set 6 | nanzhang
# Processing Record 38 of Set 6 | bluefield
# Processing Record 39 of Set 6 | bell ville
# Processing Record 40 of Set 6 | hualmay
# Processing Record 41 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 6 | totness
# Processing Record 43 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 6 | sisophon
# Processing Record 45 of Set 6 | taitung
# Processing Record 46 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 48 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 6 | tatvan
# Processing Record 50 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 1 of Set 7 | bongandanga
# Processing Record 2 of Set 7 | lavrentiya
# Processing Record 3 of Set 7 | cherdyn
# Processing Record 4 of Set 7 | plouzane
# Processing Record 5 of Set 7 | abha
# Processing Record 6 of Set 7 | northam
# Processing Record 7 of Set 7 | korla
# Processing Record 8 of Set 7 | rantepao
# Processing Record 9 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 7 | labuhan
# Processing Record 11 of Set 7 | paita
# Processing Record 12 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 7 | kendari
# Processing Record 14 of Set 7 | emerald
# Processing Record 15 of Set 7 | touros
# Processing Record 16 of Set 7 | geneva
# Processing Record 17 of Set 7 | upernavik
# Processing Record 18 of Set 7 | chapadinha
# Processing Record 19 of Set 7 | maharajganj
# Processing Record 20 of Set 7 | grindavik
# Processing Record 21 of Set 7 | roela
# Processing Record 22 of Set 7 | tiksi
# Processing Record 23 of Set 7 | bowen
# Processing Record 24 of Set 7 | ahuimanu
# Processing Record 25 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 7 | laguna
# Processing Record 27 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 7 | vila franca do campo
# Processing Record 29 of Set 7 | yeppoon
# Processing Record 30 of Set 7 | mount gambier
# Processing Record 31 of Set 7 | shache
# Processing Record 32 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 7 | port blair
# Processing Record 34 of Set 7 | russell
# Processing Record 35 of Set 7 | staunton
# Processing Record 36 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 37 of Set 7 | soyo
# Processing Record 38 of Set 7 | ostrovnoy
# Processing Record 39 of Set 7 | gornopravdinsk
# Processing Record 40 of Set 7 | antalaha
# Processing Record 41 of Set 7 | lorengau
# Processing Record 42 of Set 7 | nouadhibou
# Processing Record 43 of Set 7 | filadelfia
# Processing Record 44 of Set 7 | alice springs
# Processing Record 45 of Set 7 | lasa
# Processing Record 46 of Set 7 | nemuro
# Processing Record 47 of Set 7 | provideniya
# Processing Record 48 of Set 7 | freeport
# Processing Record 49 of Set 7 | cayenne
# Processing Record 50 of Set 7 | hamilton
# Processing Record 1 of Set 8 | dhidhdhoo
# Processing Record 2 of Set 8 | cherskiy
# Processing Record 3 of Set 8 | kavieng
# Processing Record 4 of Set 8 | xiangfan
# Processing Record 5 of Set 8 | stadtallendorf
# Processing Record 6 of Set 8 | carauari
# Processing Record 7 of Set 8 | praxedis guerrero
# Processing Record 8 of Set 8 | fairbanks
# Processing Record 9 of Set 8 | nhulunbuy
# Processing Record 10 of Set 8 | pangnirtung
# Processing Record 11 of Set 8 | saint-ambroise
# Processing Record 12 of Set 8 | verkhnevilyuysk
# Processing Record 13 of Set 8 | umm lajj
# Processing Record 14 of Set 8 | beba
# Processing Record 15 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 8 | tasiilaq
# Processing Record 17 of Set 8 | surab
# Processing Record 18 of Set 8 | rio grande
# Processing Record 19 of Set 8 | yelanskiy
# Processing Record 20 of Set 8 | mangrol
# Processing Record 21 of Set 8 | rosetta
# Processing Record 22 of Set 8 | ourinhos
# Processing Record 23 of Set 8 | sechura
# Processing Record 24 of Set 8 | karratha
# Processing Record 25 of Set 8 | nova olimpia
# Processing Record 26 of Set 8 | anadyr
# Processing Record 27 of Set 8 | san vicente de canete
# Processing Record 28 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 8 | bontang
# Processing Record 30 of Set 8 | sokol
# Processing Record 31 of Set 8 | maceio
# Processing Record 32 of Set 8 | grand gaube
# Processing Record 33 of Set 8 | cap malheureux
# Processing Record 34 of Set 8 | ribeira grande
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | abadiania
# Processing Record 37 of Set 8 | fare
# Processing Record 38 of Set 8 | kuusamo
# Processing Record 39 of Set 8 | roald
# Processing Record 40 of Set 8 | victoria
# Processing Record 41 of Set 8 | kahului
# Processing Record 42 of Set 8 | vestmanna
# Processing Record 43 of Set 8 | athabasca
# Processing Record 44 of Set 8 | marsaxlokk
# Processing Record 45 of Set 8 | copiapo
# Processing Record 46 of Set 8 | guadalupe y calvo
# Processing Record 47 of Set 8 | bethel
# Processing Record 48 of Set 8 | ust-maya
# Processing Record 49 of Set 8 | college
# Processing Record 50 of Set 8 | effingham
# Processing Record 1 of Set 9 | kuroiso
# Processing Record 2 of Set 9 | samana
# Processing Record 3 of Set 9 | mareeba
# Processing Record 4 of Set 9 | reforma
# Processing Record 5 of Set 9 | turukhansk
# Processing Record 6 of Set 9 | avera
# Processing Record 7 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 9 | nioro
# Processing Record 9 of Set 9 | progreso
# Processing Record 10 of Set 9 | bridlington
# Processing Record 11 of Set 9 | parambu
# Processing Record 12 of Set 9 | guerrero negro
# Processing Record 13 of Set 9 | bereda
# Processing Record 14 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 9 | vestmannaeyjar
# Processing Record 16 of Set 9 | poum
# Processing Record 17 of Set 9 | mirnyy
# Processing Record 18 of Set 9 | kofarnihon
# City not found. Skipping...
# Processing Record 19 of Set 9 | la romana
# Processing Record 20 of Set 9 | hofn
# Processing Record 21 of Set 9 | callaway
# Processing Record 22 of Set 9 | shediac
# Processing Record 23 of Set 9 | williams lake
# Processing Record 24 of Set 9 | darnah
# Processing Record 25 of Set 9 | tuatapere
# Processing Record 26 of Set 9 | baykit
# Processing Record 27 of Set 9 | dzhalil
# Processing Record 28 of Set 9 | dicabisagan
# Processing Record 29 of Set 9 | coihaique
# Processing Record 30 of Set 9 | te anau
# Processing Record 31 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 9 | jiazi
# Processing Record 33 of Set 9 | oystese
# Processing Record 34 of Set 9 | isangel
# Processing Record 35 of Set 9 | shakawe
# Processing Record 36 of Set 9 | saint-joseph
# Processing Record 37 of Set 9 | faanui
# Processing Record 38 of Set 9 | illapel
# Processing Record 39 of Set 9 | ambagarh chauki
# Processing Record 40 of Set 9 | vostok
# Processing Record 41 of Set 9 | pitimbu
# Processing Record 42 of Set 9 | boysun
# Processing Record 43 of Set 9 | xunchang
# Processing Record 44 of Set 9 | sorland
# Processing Record 45 of Set 9 | ayotzintepec
# Processing Record 46 of Set 9 | sitka
# Processing Record 47 of Set 9 | oum hadjer
# Processing Record 48 of Set 9 | liverpool
# Processing Record 49 of Set 9 | necochea
# Processing Record 50 of Set 9 | fuyu
# Processing Record 1 of Set 10 | saint augustine
# Processing Record 2 of Set 10 | robertsport
# Processing Record 3 of Set 10 | sorong
# Processing Record 4 of Set 10 | henties bay
# Processing Record 5 of Set 10 | dom pedrito
# Processing Record 6 of Set 10 | cidreira
# Processing Record 7 of Set 10 | urucara
# Processing Record 8 of Set 10 | talnakh
# Processing Record 9 of Set 10 | rantauprapat
# Processing Record 10 of Set 10 | behbahan
# Processing Record 11 of Set 10 | megion
# Processing Record 12 of Set 10 | buin
# Processing Record 13 of Set 10 | allanridge
# Processing Record 14 of Set 10 | preobrazheniye
# Processing Record 15 of Set 10 | piopio
# Processing Record 16 of Set 10 | san rafael
# Processing Record 17 of Set 10 | hovd
# Processing Record 18 of Set 10 | shinshiro
# Processing Record 19 of Set 10 | santana do livramento
# Processing Record 20 of Set 10 | saint george
# Processing Record 21 of Set 10 | atar
# Processing Record 22 of Set 10 | mastic beach
# Processing Record 23 of Set 10 | takoradi
# Processing Record 24 of Set 10 | sorrento
# Processing Record 25 of Set 10 | valparaiso
# Processing Record 26 of Set 10 | najran
# Processing Record 27 of Set 10 | asau
# Processing Record 28 of Set 10 | tokmak
# Processing Record 29 of Set 10 | batu
# Processing Record 30 of Set 10 | outlook
# Processing Record 31 of Set 10 | kiruna
# Processing Record 32 of Set 10 | lockport
# Processing Record 33 of Set 10 | antigonish
# Processing Record 34 of Set 10 | waingapu
# Processing Record 35 of Set 10 | srednekolymsk
# Processing Record 36 of Set 10 | ilulissat
# Processing Record 37 of Set 10 | sapouy
# Processing Record 38 of Set 10 | berlevag
# Processing Record 39 of Set 10 | ponta delgada
# Processing Record 40 of Set 10 | oudtshoorn
# Processing Record 41 of Set 10 | zheleznodorozhnyy
# Processing Record 42 of Set 10 | egvekinot
# Processing Record 43 of Set 10 | manaus
# Processing Record 44 of Set 10 | salvador
# Processing Record 45 of Set 10 | padang
# Processing Record 46 of Set 10 | kautokeino
# Processing Record 47 of Set 10 | namatanai
# Processing Record 48 of Set 10 | saravena
# Processing Record 49 of Set 10 | santo domingo
# Processing Record 50 of Set 10 | lichinga
# Processing Record 1 of Set 11 | chapayevka
# Processing Record 2 of Set 11 | bonavista
# Processing Record 3 of Set 11 | ganzhou
# Processing Record 4 of Set 11 | lanquin
# Processing Record 5 of Set 11 | kalmunai
# Processing Record 6 of Set 11 | dingle
# Processing Record 7 of Set 11 | isla vista
# Processing Record 8 of Set 11 | dwarka
# Processing Record 9 of Set 11 | port keats
# Processing Record 10 of Set 11 | carutapera
# Processing Record 11 of Set 11 | taksimo
# Processing Record 12 of Set 11 | san luis
# Processing Record 13 of Set 11 | jaque
# Processing Record 14 of Set 11 | damghan
# Processing Record 15 of Set 11 | zharkent
# Processing Record 16 of Set 11 | marsh harbour
# Processing Record 17 of Set 11 | hasaki
# Processing Record 18 of Set 11 | xinyu
# Processing Record 19 of Set 11 | jimenez
# Processing Record 20 of Set 11 | kargasok
# Processing Record 21 of Set 11 | port macquarie
# Processing Record 22 of Set 11 | dudinka
# Processing Record 23 of Set 11 | kilakarai
# Processing Record 24 of Set 11 | asyut
# Processing Record 25 of Set 11 | dawlatabad
# Processing Record 26 of Set 11 | kholodnyy
# Processing Record 27 of Set 11 | maun
# Processing Record 28 of Set 11 | ullapool
# Processing Record 29 of Set 11 | bayan
# Processing Record 30 of Set 11 | hope
# Processing Record 31 of Set 11 | kudahuvadhoo
# Processing Record 32 of Set 11 | oktyabrskoye
# Processing Record 33 of Set 11 | kununurra
# Processing Record 34 of Set 11 | morehead
# Processing Record 35 of Set 11 | mathathane
# Processing Record 36 of Set 11 | kupang
# Processing Record 37 of Set 11 | saldanha
# Processing Record 38 of Set 11 | ust-tsilma
# Processing Record 39 of Set 11 | yarmouth
# Processing Record 40 of Set 11 | codrington
# Processing Record 41 of Set 11 | bay roberts
# Processing Record 42 of Set 11 | samarai
# Processing Record 43 of Set 11 | khokholskiy
# City not found. Skipping...
# Processing Record 44 of Set 11 | quang ngai
# Processing Record 45 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 11 | havoysund
# Processing Record 47 of Set 11 | san isidro
# Processing Record 48 of Set 11 | kameoka
# Processing Record 49 of Set 11 | zimovniki
# Processing Record 50 of Set 11 | palana
# Processing Record 1 of Set 12 | oranjestad
# Processing Record 2 of Set 12 | ratnagiri
# Processing Record 3 of Set 12 | qui nhon
# Processing Record 4 of Set 12 | nerang
# Processing Record 5 of Set 12 | ust-ishim
# Processing Record 6 of Set 12 | ocos
# Processing Record 7 of Set 12 | jalu
# Processing Record 8 of Set 12 | darbhanga
# Processing Record 9 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 12 | iralaya
# Processing Record 11 of Set 12 | rabak
# Processing Record 12 of Set 12 | clearwater
# Processing Record 13 of Set 12 | key west
# Processing Record 14 of Set 12 | sisimiut
# Processing Record 15 of Set 12 | abu samrah
# Processing Record 16 of Set 12 | baghdad
# Processing Record 17 of Set 12 | sukheke
# City not found. Skipping...
# Processing Record 18 of Set 12 | nizhniy kuranakh
# Processing Record 19 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 12 | tomatlan
# Processing Record 21 of Set 12 | port angeles
# Processing Record 22 of Set 12 | vinh
# Processing Record 23 of Set 12 | graaff-reinet
# Processing Record 24 of Set 12 | alvaraes
# Processing Record 25 of Set 12 | bingerville
# Processing Record 26 of Set 12 | bayir
# Processing Record 27 of Set 12 | namie
# Processing Record 28 of Set 12 | youkounkoun
# Processing Record 29 of Set 12 | hit
# Processing Record 30 of Set 12 | puerto el triunfo
# Processing Record 31 of Set 12 | sao jose da coroa grande
# Processing Record 32 of Set 12 | alfreton
# Processing Record 33 of Set 12 | kraksaan
# Processing Record 34 of Set 12 | dharchula
# Processing Record 35 of Set 12 | lipin bor
# Processing Record 36 of Set 12 | aksarka
# Processing Record 37 of Set 12 | lodja
# Processing Record 38 of Set 12 | aquiraz
# Processing Record 39 of Set 12 | akdepe
# Processing Record 40 of Set 12 | barstow
# Processing Record 41 of Set 12 | bonthe
# Processing Record 42 of Set 12 | humaita
# Processing Record 43 of Set 12 | ende
# Processing Record 44 of Set 12 | evensk
# Processing Record 45 of Set 12 | faya
# Processing Record 46 of Set 12 | tarnos
# Processing Record 47 of Set 12 | burica
# City not found. Skipping...
# Processing Record 48 of Set 12 | bialystok
# Processing Record 49 of Set 12 | venado tuerto
# Processing Record 50 of Set 12 | los llanos de aridane
# Processing Record 1 of Set 13 | luanda
# Processing Record 2 of Set 13 | algiers
# Processing Record 3 of Set 13 | saint-augustin
# Processing Record 4 of Set 13 | zhongshu
# Processing Record 5 of Set 13 | porto velho
# Processing Record 6 of Set 13 | bac lieu
# Processing Record 7 of Set 13 | hanmer springs
# Processing Record 8 of Set 13 | ayaviri
# Processing Record 9 of Set 13 | monrovia
# Processing Record 10 of Set 13 | great falls
# Processing Record 11 of Set 13 | odienne
# Processing Record 12 of Set 13 | tromso
# Processing Record 13 of Set 13 | morristown
# Processing Record 14 of Set 13 | rizhao
# Processing Record 15 of Set 13 | verkh-chebula
# Processing Record 16 of Set 13 | asfi
# Processing Record 17 of Set 13 | le mars
# Processing Record 18 of Set 13 | tiznit
# Processing Record 19 of Set 13 | coihueco
# Processing Record 20 of Set 13 | vadso
# Processing Record 21 of Set 13 | sangar
# Processing Record 22 of Set 13 | arlit
# Processing Record 23 of Set 13 | bodden town
# Processing Record 24 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 25 of Set 13 | meulaboh
# Processing Record 26 of Set 13 | noumea
# Processing Record 27 of Set 13 | torbay
# Processing Record 28 of Set 13 | grants
# Processing Record 29 of Set 13 | almenara
# Processing Record 30 of Set 13 | viedma
# Processing Record 31 of Set 13 | tillabery
# City not found. Skipping...
# Processing Record 32 of Set 13 | haflong
# Processing Record 33 of Set 13 | businga
# Processing Record 34 of Set 13 | clearlake
# Processing Record 35 of Set 13 | micheweni
# Processing Record 36 of Set 13 | chatakonda
# Processing Record 37 of Set 13 | luena
# Processing Record 38 of Set 13 | nantucket
# Processing Record 39 of Set 13 | marawi
# Processing Record 40 of Set 13 | maraial
# Processing Record 41 of Set 13 | winchester
# Processing Record 42 of Set 13 | batagay
# Processing Record 43 of Set 13 | anqing
# Processing Record 44 of Set 13 | maumere
# Processing Record 45 of Set 13 | chitungwiza
# Processing Record 46 of Set 13 | sala
# Processing Record 47 of Set 13 | sharan
# Processing Record 48 of Set 13 | mukhen
# Processing Record 49 of Set 13 | valley city
# Processing Record 50 of Set 13 | udachnyy
# Processing Record 1 of Set 14 | gigmoto
# Processing Record 2 of Set 14 | sabya
# Processing Record 3 of Set 14 | rodrigues alves
# Processing Record 4 of Set 14 | toba
# Processing Record 5 of Set 14 | olinda
# Processing Record 6 of Set 14 | shibetsu
# Processing Record 7 of Set 14 | siocon
# Processing Record 8 of Set 14 | uglovskoye
# Processing Record 9 of Set 14 | tortoli
# Processing Record 10 of Set 14 | aliganj
# Processing Record 11 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 12 of Set 14 | vila velha
# Processing Record 13 of Set 14 | adrar
# Processing Record 14 of Set 14 | vasudevanallur
# Processing Record 15 of Set 14 | praia
# Processing Record 16 of Set 14 | caraquet
# Processing Record 17 of Set 14 | seddon
# Processing Record 18 of Set 14 | lala
# Processing Record 19 of Set 14 | bahir dar
# Processing Record 20 of Set 14 | saint-georges
# Processing Record 21 of Set 14 | sao joao da barra
# Processing Record 22 of Set 14 | solnechnyy
# Processing Record 23 of Set 14 | snezhnogorsk
# Processing Record 24 of Set 14 | batticaloa
# Processing Record 25 of Set 14 | voh
# Processing Record 26 of Set 14 | tobermory
# Processing Record 27 of Set 14 | manzhouli
# Processing Record 28 of Set 14 | galveston
# Processing Record 29 of Set 14 | beawar
# Processing Record 30 of Set 14 | margate
# Processing Record 31 of Set 14 | alyangula
# Processing Record 32 of Set 14 | carpentras
# Processing Record 33 of Set 14 | bystryy istok
# Processing Record 34 of Set 14 | catuday
# Processing Record 35 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 36 of Set 14 | chegutu
# Processing Record 37 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 14 | bitonto
# Processing Record 39 of Set 14 | saint-pierre
# Processing Record 40 of Set 14 | timizart
# Processing Record 41 of Set 14 | mnogovershinnyy
# Processing Record 42 of Set 14 | pouebo
# Processing Record 43 of Set 14 | shatura
# Processing Record 44 of Set 14 | killybegs
# Processing Record 45 of Set 14 | owando
# Processing Record 46 of Set 14 | muscatine
# Processing Record 47 of Set 14 | umba
# Processing Record 48 of Set 14 | gonen
# Processing Record 49 of Set 14 | kamenka
# Processing Record 50 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 15 | saint-paul
# Processing Record 2 of Set 15 | boca do acre
# Processing Record 3 of Set 15 | bay-khaak
# Processing Record 4 of Set 15 | lagos
# Processing Record 5 of Set 15 | palu
# Processing Record 6 of Set 15 | ola
# Processing Record 7 of Set 15 | aklavik
# Processing Record 8 of Set 15 | mengcheng
# Processing Record 9 of Set 15 | jiuquan
# Processing Record 10 of Set 15 | teguise
# Processing Record 11 of Set 15 | griffith
# Processing Record 12 of Set 15 | dekar
# Processing Record 13 of Set 15 | gaziantep
# Processing Record 14 of Set 15 | ndele
# Processing Record 15 of Set 15 | la sarre
# Processing Record 16 of Set 15 | qaqortoq
# Processing Record 17 of Set 15 | mont-de-marsan
# Processing Record 18 of Set 15 | mamallapuram
# Processing Record 19 of Set 15 | matara
# Processing Record 20 of Set 15 | sabalgarh
# Processing Record 21 of Set 15 | quesnel
# Processing Record 22 of Set 15 | alta floresta
# Processing Record 23 of Set 15 | inhambane
# Processing Record 24 of Set 15 | yima
# Processing Record 25 of Set 15 | novikovo
# Processing Record 26 of Set 15 | coahuayana
# Processing Record 27 of Set 15 | canmore
# Processing Record 28 of Set 15 | victor harbor
# Processing Record 29 of Set 15 | ankang
# Processing Record 30 of Set 15 | kyaikto
# Processing Record 31 of Set 15 | brae
# Processing Record 32 of Set 15 | ranong
# Processing Record 33 of Set 15 | burnie
# Processing Record 34 of Set 15 | barcelos
# Processing Record 35 of Set 15 | la ronge
# Processing Record 36 of Set 15 | menongue
# Processing Record 37 of Set 15 | kattivakkam
# Processing Record 38 of Set 15 | mananjary
# Processing Record 39 of Set 15 | wuhan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vaini      TO -21.2000 -175.2000     75.36        94          20
# 1   Puerto Ayora      EC  -0.7393  -90.3518     84.16        82          32
# 2     Georgetown      MY   5.4112  100.3354     82.33        98          20
# 3    San Quintin      MX  30.4833 -115.9500     66.20        64           5
# 4  Pacific Grove      US  36.6177 -121.9166     60.91        81         100
# 5          Alofi      NU -19.0595 -169.9187     71.49       100          95
# 6         Kodiak      US  57.7900 -152.4072     54.91        62           0
# 7      Cape Town      ZA -33.9258   18.4232     60.91        87           0
# 8       Olafsvik      IS  64.8945  -23.7142     47.07        69           9
# 9        Ushuaia      AR -54.8000  -68.3000     37.06        87          40
#
#    Wind Speed Current Description
# 0        5.75          few clouds
# 1       11.01    scattered clouds
# 2        3.44          few clouds
# 3       13.80           clear sky
# 4        8.01     overcast clouds
# 5        2.30     overcast clouds
# 6        5.75           clear sky
# 7        5.75           clear sky
# 8        9.10           clear sky
# 9       29.93          light rain

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
